# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
from PIL import Image
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords 
from wordcloud import WordCloud, STOPWORDS ,ImageColorGenerator

# %%
df = pd.read_csv('Tweeter_Data_IN.csv')

# %%
df.head()
# Out:
#                        created_at                        hashtags  \
# 0  Wed Mar 25 06:20:02 +0000 2020                             NaN
# 1  Wed Mar 25 06:36:25 +0000 2020                             NaN
# 2  Wed Mar 25 06:18:32 +0000 2020                             NaN
# 3  Wed Mar 25 06:05:46 +0000 2020   SSC_UFM_MAT_KARONA Corona UFM
# 4  Wed Mar 25 06:31:10 +0000 2020  Corona pritamkumarmurari Voice
#
#    favorite_count                   id lang                     place  \
# 0               0  1242697733175220000   en               Pune, India
# 1               0  1242701857253980000   en        Gandhinagar, India
# 2               0  1242697356249880000   en       Bidhan Nagar, India
# 3               9  1242694142242650000   en        Maharashtra, India
# 4               0  1242700536752700000   en  Bokaro Steel City, India
#
#    retweet_count                                               text  \
# 0              0  Meditation and mindfulness tips for coping wit...
# 1              0  Contribute to INDIA FIGHTS CORONA @ Gandhinaga...
# 2              0  @DelhiPolice @DCPEastDelhi @msisodia @AamAadmi...
# 3             19  #SSC_UFM_MAT_KARONA\n#Corona is slow poison #U...
# 4              0  https://t.co/P7eQiq8tFa Mata Di \nDoston ise #...
#
#                                            tweet_url user_screen_name  \
# 0  https://twitter.com/ShalomFloat/status/1242697...      ShalomFloat
# 1  https://twitter.com/prakashkalal/status/124270...     prakashkalal
# 2  https://twitter.com/Bhartendulkar/status/12426...    Bhartendulkar
# 3  https://twitter.com/patilkiii/status/124269414...        patilkiii
# 4  https://twitter.com/SINGERMurariPa1/status/124...  SINGERMurariPa1
#
#                                     user_description  user_favourites_count  \
# 0  Shalom float spa is the first dedicated float ...                    252
# 1                                                NaN                    693
# 2  Senior Media Analyst @Indianpac | Ex Sr Report...                   5273
# 3  Ab khushi de ke aazma le khuda, In ghamon se t...                   1744
# 4               Singing,Dancing,Acting,Entertainment                      4
#
#    user_followers_count  user_friends_count  user_listed_count  \
# 0                   382                  97                 24
# 1                   175                 107                  0
# 2                   609                2239                  7
# 3                   259                 786                  0
# 4                     2                 163                  0
#
#                                        user_location  \
# 0                                              India
# 1                                 Gandhinagar, India
# 2                                     Kolkata, India
# 3                                        Pune, India
# 4  ‡§¨‡•ã‡§ï‡§æ‡§∞‡•ã ‡§∏‡•ç‡§ü‡•Ä‡§≤ ‡§∏‡§ø‡§ü‡•...
#
#                                            user_name user_screen_name.1  \
# 0                                   Shalom Float Spa        ShalomFloat
# 1                                              prks7       prakashkalal
# 2                                   Bhartendu Sharma      Bhartendulkar
# 3  ùï¨ùñáùñçùñéùñëùñÜùñòùñç ùïæùñöùñì...          patilkiii
# 4                               SINGER=Murari Pathak    SINGERMurariPa1
#
#    user_statuses_count
# 0                 1770
# 1                   73
# 2                 6002
# 3                 1387
# 4                   13

# %%
allWords = ' '.join([twts for twts in df['text']])

# %% [markdown]
# ### Filtering allwords :

# %% [markdown]
# The text **allwords** contains some useless characters like á,Æ,ü,è,ô,Ä etc. so first characters like these have to be removed and a filtered text file has to be created to construct a meaningful wordcloud.

# %%
filtered_allwords=''

for charr in allWords :
    if ord(charr)<126 :
        filtered_allwords = filtered_allwords + charr

# %% [markdown]
# ### Creating wordcloud from filtered allwords

# %%
mask = np.array(Image.open('C:\\Users\\user\\Desktop\\image1.png'))
stopwords = set(STOPWORDS)
stopwords.update(['https', 'co','t','d','n','viru'])

wc = WordCloud(background_color='white',stopwords=stopwords,mask=mask,
               contour_width=30,contour_color='lightblue',max_font_size=400,max_words=225)
wc.generate(filtered_allwords)


plt.figure(figsize=(14,10),facecolor='k')
plt.axis('off')
plt.imshow(wc,interpolation='bilinear')
plt.show();

# %% [markdown]
# -------
# # Showing popular hashtags
# -------

# %%
df.text.str.extractall(r'(#\w+)')[0].value_counts()
# Out:
# #Corona                    2736
# #COVID                     1921
# #COVID19                   1797
# #corona                    1715
# #coronavirus               1452
#                            ...
# #Coronavirus_COVID20          1
# #sunarjewels                  1
# #Lockdown_MuslimsRelief       1
# #TwoChildPolicy               1
# #loveinthetimeofcovid19       1
# Name: 0, Length: 15092, dtype: int64

# %%
hashtag_df = pd.DataFrame(df.text.str.extractall(r'(#\w+)')[0].value_counts())

# %%
hashtag_df.reset_index(inplace=True)

# %%
hashtag_df.columns=['Hashtag','Frequency']

# %%
len(hashtag_df)
# Out:
# 15092

# %%
sum(hashtag_df['Frequency'])
# Out:
# 60586

# %% [markdown]
# -----
# **Removing '#' symbols from text for better readability**

# %%
hashtag_df.head(20)
# Out:
#                  Hashtag  Frequency
# 0                #Corona       2736
# 1                 #COVID       1921
# 2               #COVID19       1797
# 3                #corona       1715
# 4           #coronavirus       1452
# 5     #IndiaFightsCorona       1128
# 6              #lockdown        996
# 7              #Covid_19        545
# 8      #StayHomeStaySafe        484
# 9               #covid19        476
# 10            #COVID2019        438
# 11             #StayHome        437
# 12                #India        385
# 13     #coronavirusindia        381
# 14              #Covid19        352
# 15             #stayhome        339
# 16             #staysafe        313
# 17  #CoronavirusOutbreak        299
# 18       #CoronaWarriors        275
# 19        #21daylockdown        261

# %%
def remove(word) :
    return word[1:]

# %%
hashtag_df['Hashtag'] = hashtag_df['Hashtag'].apply(remove)

# %%
hashtag_df.head(20)
# Out:
#                 Hashtag  Frequency
# 0                Corona       2736
# 1                 COVID       1921
# 2               COVID19       1797
# 3                corona       1715
# 4           coronavirus       1452
# 5     IndiaFightsCorona       1128
# 6              lockdown        996
# 7              Covid_19        545
# 8      StayHomeStaySafe        484
# 9               covid19        476
# 10            COVID2019        438
# 11             StayHome        437
# 12                India        385
# 13     coronavirusindia        381
# 14              Covid19        352
# 15             stayhome        339
# 16             staysafe        313
# 17  CoronavirusOutbreak        299
# 18       CoronaWarriors        275
# 19        21daylockdown        261

# %%
plt.figure(figsize=(16,6),dpi=300)

sns.barplot(x=hashtag_df['Hashtag'].head(20),y=hashtag_df['Frequency'].head(20))
plt.xticks(rotation=(45))
plt.title('Most used Hashtags');

# %%
hashtag_df.set_index('Hashtag').head(20).plot.pie(y='Frequency',radius=2.5,autopct="%.1f%%",legend=None)
plt.ylabel("");

# %% [markdown]
# **_The popularity of a hashtag also depends on the no. the retweets the tweet containing that hashtag got. So below is the hashtags present in top 5 most retweeted tweets._**

# %%
top5 = df['retweet_count'].sort_values(ascending=False).head(5)

# %%
top5
# Out:
# 8889     22549
# 22960     3820
# 38007     1830
# 12318     1769
# 40052     1691
# Name: retweet_count, dtype: int64

# %% [markdown]
# ## Most Retweeted Tweet

# %% [markdown]
# _It is by famous indian cricketer **Suresh Raina** who is tweeting about making donations to help fight the novel coronavirus_.

# %%
df.iloc[df['retweet_count'].argmax()]['text']
# Out:
# 'It‚Äôs time we all do our bit to help defeat #COVID19. I‚Äôm pledging ‚Çπ52 lakh for the fight against #Corona (‚Çπ31 lakh to the  PM-CARES Fund &amp; ‚Çπ21 lakh to the UP CM‚Äôs Disaster Relief Fund). Please do your bit too. Jai Hind!#StayHomeIndia @narendramodi @PMOIndia @myogiadityanath'

# %%
df.iloc[df['retweet_count'].argmax()]['user_screen_name']
# Out:
# 'ImRaina'

# %% [markdown]
# -------
#
# # Showing popular users
# -------

# %%
df.text.str.extractall(r'(\@\w+)')[0].value_counts()
# Out:
# @narendramodi       3778
# @PMOIndia           2779
# @ArvindKejriwal      746
# @AmitShah            742
# @MoHFW_INDIA         541
#                     ...
# @Komal_Indian          1
# @ChrisEvans            1
# @eshagupta2811         1
# @nammsiem              1
# @drbalajimanohar       1
# Name: 0, Length: 15453, dtype: int64

# %%
users_df = pd.DataFrame(df.text.str.extractall(r'(\@\w+)')[0].value_counts())

# %%
users_df.reset_index(inplace=True)

# %%
users_df.columns=['Twitter handles','Tweets']

# %%
users_df.head(20)
# Out:
#      Twitter handles  Tweets
# 0      @narendramodi    3778
# 1          @PMOIndia    2779
# 2    @ArvindKejriwal     746
# 3          @AmitShah     742
# 4       @MoHFW_INDIA     541
# 5   @myogiadityanath     521
# 6    @CMOMaharashtra     496
# 7       @RahulGandhi     482
# 8            @aajtak     429
# 9         @BJP4India     355
# 10              @WHO     347
# 11   @drharshvardhan     329
# 12  @realDonaldTrump     309
# 13         @HMOIndia     293
# 14         @INCIndia     290
# 15      @nsitharaman     279
# 16      @AUThackeray     275
# 17       @OfficeofUT     275
# 18           @KTRTRS     267
# 19          @ABPNews     265

# %%
len(users_df)
# Out:
# 15453

# %%
sum(users_df['Tweets'])
# Out:
# 59957

# %% [markdown]
# -----
# **Removing '@' symbols from text for better readability**

# %%
def remove(word) :
    return word[1:]

# %%
users_df['Twitter handles']=users_df['Twitter handles'].apply(remove)

# %%
users_df.head(20)
# Out:
#     Twitter handles  Tweets
# 0      narendramodi    3778
# 1          PMOIndia    2779
# 2    ArvindKejriwal     746
# 3          AmitShah     742
# 4       MoHFW_INDIA     541
# 5   myogiadityanath     521
# 6    CMOMaharashtra     496
# 7       RahulGandhi     482
# 8            aajtak     429
# 9         BJP4India     355
# 10              WHO     347
# 11   drharshvardhan     329
# 12  realDonaldTrump     309
# 13         HMOIndia     293
# 14         INCIndia     290
# 15      nsitharaman     279
# 16      AUThackeray     275
# 17       OfficeofUT     275
# 18           KTRTRS     267
# 19          ABPNews     265

# %%
plt.figure(figsize=(16,6),dpi=300)

sns.barplot(x=users_df['Twitter handles'].head(20),y=users_df['Tweets'].head(20))
plt.xticks(rotation=(45))
plt.title('Most Dominant twitter Handles');

# %%
users_df.set_index('Twitter handles').head(20).plot.pie(y='Tweets',radius=2.5,autopct="%.1f%%",legend=None)
plt.ylabel("");

# %% [markdown]
# ### Top 5 most followed users

# %%
df['user_followers_count'].argsort()[-5:]
# Out:
# 44174    36708
# 44175    26221
# 44176    30858
# 44177    41151
# 44178     8889
# Name: user_followers_count, dtype: int64

# %%
for count in df['user_followers_count'].argsort()[-5:] :
    print(df.iloc[count]['user_screen_name'])
# Out:
# AnilKapoor
# thekiranbedi
# thekiranbedi
# thekiranbedi
# ImRaina

# %% [markdown]
# # Monthly analysis
# -------
# here we will analyze monthwise trend of tweets

# %%
df.head()
# Out:
#                        created_at                        hashtags  \
# 0  Wed Mar 25 06:20:02 +0000 2020                             NaN
# 1  Wed Mar 25 06:36:25 +0000 2020                             NaN
# 2  Wed Mar 25 06:18:32 +0000 2020                             NaN
# 3  Wed Mar 25 06:05:46 +0000 2020   SSC_UFM_MAT_KARONA Corona UFM
# 4  Wed Mar 25 06:31:10 +0000 2020  Corona pritamkumarmurari Voice
#
#    favorite_count                   id lang                     place  \
# 0               0  1242697733175220000   en               Pune, India
# 1               0  1242701857253980000   en        Gandhinagar, India
# 2               0  1242697356249880000   en       Bidhan Nagar, India
# 3               9  1242694142242650000   en        Maharashtra, India
# 4               0  1242700536752700000   en  Bokaro Steel City, India
#
#    retweet_count                                               text  \
# 0              0  Meditation and mindfulness tips for coping wit...
# 1              0  Contribute to INDIA FIGHTS CORONA @ Gandhinaga...
# 2              0  @DelhiPolice @DCPEastDelhi @msisodia @AamAadmi...
# 3             19  #SSC_UFM_MAT_KARONA\n#Corona is slow poison #U...
# 4              0  https://t.co/P7eQiq8tFa Mata Di \nDoston ise #...
#
#                                            tweet_url user_screen_name  \
# 0  https://twitter.com/ShalomFloat/status/1242697...      ShalomFloat
# 1  https://twitter.com/prakashkalal/status/124270...     prakashkalal
# 2  https://twitter.com/Bhartendulkar/status/12426...    Bhartendulkar
# 3  https://twitter.com/patilkiii/status/124269414...        patilkiii
# 4  https://twitter.com/SINGERMurariPa1/status/124...  SINGERMurariPa1
#
#                                     user_description  user_favourites_count  \
# 0  Shalom float spa is the first dedicated float ...                    252
# 1                                                NaN                    693
# 2  Senior Media Analyst @Indianpac | Ex Sr Report...                   5273
# 3  Ab khushi de ke aazma le khuda, In ghamon se t...                   1744
# 4               Singing,Dancing,Acting,Entertainment                      4
#
#    user_followers_count  user_friends_count  user_listed_count  \
# 0                   382                  97                 24
# 1                   175                 107                  0
# 2                   609                2239                  7
# 3                   259                 786                  0
# 4                     2                 163                  0
#
#                                        user_location  \
# 0                                              India
# 1                                 Gandhinagar, India
# 2                                     Kolkata, India
# 3                                        Pune, India
# 4  ‡§¨‡•ã‡§ï‡§æ‡§∞‡•ã ‡§∏‡•ç‡§ü‡•Ä‡§≤ ‡§∏‡§ø‡§ü‡•...
#
#                                            user_name user_screen_name.1  \
# 0                                   Shalom Float Spa        ShalomFloat
# 1                                              prks7       prakashkalal
# 2                                   Bhartendu Sharma      Bhartendulkar
# 3  ùï¨ùñáùñçùñéùñëùñÜùñòùñç ùïæùñöùñì...          patilkiii
# 4                               SINGER=Murari Pathak    SINGERMurariPa1
#
#    user_statuses_count
# 0                 1770
# 1                   73
# 2                 6002
# 3                 1387
# 4                   13

# %% [markdown]
# Creating 'dates' column by extracting dates from 'created_at' column of original dataframe

# %%
df['dates'] = pd.to_datetime(df['created_at'])

# %% [markdown]
# **Extracting months from 'dates' column and dropping 'dates' column as it is now redundant**

# %%
df['month'] = pd.DatetimeIndex(df['dates']).month

# %%
df.drop('dates',axis=1,inplace=True)

# %% [markdown]
# **_Checking how many different months' data we have_**

# %%
df['month'].unique()
# Out:
# array([3, 4, 5], dtype=int64)

# %%
df['month']=df['month'].map({3:'March',4:'April',5:'May'})

# %%
df.head()
# Out:
#                        created_at                        hashtags  \
# 0  Wed Mar 25 06:20:02 +0000 2020                             NaN
# 1  Wed Mar 25 06:36:25 +0000 2020                             NaN
# 2  Wed Mar 25 06:18:32 +0000 2020                             NaN
# 3  Wed Mar 25 06:05:46 +0000 2020   SSC_UFM_MAT_KARONA Corona UFM
# 4  Wed Mar 25 06:31:10 +0000 2020  Corona pritamkumarmurari Voice
#
#    favorite_count                   id lang                     place  \
# 0               0  1242697733175220000   en               Pune, India
# 1               0  1242701857253980000   en        Gandhinagar, India
# 2               0  1242697356249880000   en       Bidhan Nagar, India
# 3               9  1242694142242650000   en        Maharashtra, India
# 4               0  1242700536752700000   en  Bokaro Steel City, India
#
#    retweet_count                                               text  \
# 0              0  Meditation and mindfulness tips for coping wit...
# 1              0  Contribute to INDIA FIGHTS CORONA @ Gandhinaga...
# 2              0  @DelhiPolice @DCPEastDelhi @msisodia @AamAadmi...
# 3             19  #SSC_UFM_MAT_KARONA\n#Corona is slow poison #U...
# 4              0  https://t.co/P7eQiq8tFa Mata Di \nDoston ise #...
#
#                                            tweet_url user_screen_name  \
# 0  https://twitter.com/ShalomFloat/status/1242697...      ShalomFloat
# 1  https://twitter.com/prakashkalal/status/124270...     prakashkalal
# 2  https://twitter.com/Bhartendulkar/status/12426...    Bhartendulkar
# 3  https://twitter.com/patilkiii/status/124269414...        patilkiii
# 4  https://twitter.com/SINGERMurariPa1/status/124...  SINGERMurariPa1
#
#                                     user_description  user_favourites_count  \
# 0  Shalom float spa is the first dedicated float ...                    252
# 1                                                NaN                    693
# 2  Senior Media Analyst @Indianpac | Ex Sr Report...                   5273
# 3  Ab khushi de ke aazma le khuda, In ghamon se t...                   1744
# 4               Singing,Dancing,Acting,Entertainment                      4
#
#    user_followers_count  user_friends_count  user_listed_count  \
# 0                   382                  97                 24
# 1                   175                 107                  0
# 2                   609                2239                  7
# 3                   259                 786                  0
# 4                     2                 163                  0
#
#                                        user_location  \
# 0                                              India
# 1                                 Gandhinagar, India
# 2                                     Kolkata, India
# 3                                        Pune, India
# 4  ‡§¨‡•ã‡§ï‡§æ‡§∞‡•ã ‡§∏‡•ç‡§ü‡•Ä‡§≤ ‡§∏‡§ø‡§ü‡•...
#
#                                            user_name user_screen_name.1  \
# 0                                   Shalom Float Spa        ShalomFloat
# 1                                              prks7       prakashkalal
# 2                                   Bhartendu Sharma      Bhartendulkar
# 3  ùï¨ùñáùñçùñéùñëùñÜùñòùñç ùïæùñöùñì...          patilkiii
# 4                               SINGER=Murari Pathak    SINGERMurariPa1
#
#    user_statuses_count  month
# 0                 1770  March
# 1                   73  March
# 2                 6002  March
# 3                 1387  March
# 4                   13  March

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['month'])
plt.ylabel("Number of tweets made")
plt.title('Number of tweets V/S Month');

# %% [markdown]
# ### Exploring weekday based trend of tweets

# %%
df['created_at'].head()
# Out:
# 0    Wed Mar 25 06:20:02 +0000 2020
# 1    Wed Mar 25 06:36:25 +0000 2020
# 2    Wed Mar 25 06:18:32 +0000 2020
# 3    Wed Mar 25 06:05:46 +0000 2020
# 4    Wed Mar 25 06:31:10 +0000 2020
# Name: created_at, dtype: object

# %%
df['tweet_day'] = pd.to_datetime(df['created_at']).dt.weekday

# %%
tweet_day = df['tweet_day'].value_counts().sort_index()

# %% [markdown]
# **_this plot tells about week day based trend of tweets i.e how the number of tweets made changes with days_**

# %%
plt.figure(figsize=(12,6))
plt.xticks(tweet_day.index,labels=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
df['tweet_day'].value_counts().sort_index().plot();

# %% [markdown]
# # SENTIMENT ANALYSIS

# %% [markdown]
# **_First we will have to do some preprocessing to clean the tweets so that the sentiment analysis will yield more accurate results._**

# %% [markdown]
# **1.)** Method to clean the text of the tweets.

# %%
def clean_Text(text ): 
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|\
                           (\w+:\/\/\S+)", " ", text).split())

# %% [markdown]
# **2.)** Updating default nltk stopwords and then removing them from our tweets.

# %%
stop_words = set(stopwords.words('english')) 
stop_words.add('Corona')
stop_words.add('COVID')
stop_words.add('COVID19')
stop_words.add('corona')
stop_words.add('india')
stop_words.add('coronavirus')
stop_words.add('Covid_19')
stop_words.add('twitter')
stop_words.add('Covid19')
stop_words.add('com')

# %%
def remove_stop(text ):
    words = word_tokenize(text.lower()) 
    sentence = [w for w in words if not w in stop_words]
    return " ".join(sentence)

# %% [markdown]
# **3.)** Method to compute sentiment score for tweet

# %%
def sentiment_analyzer(x ):
    return analyzer.polarity_scores(x)

# %% [markdown]
# **4.)** Method to assign sentiment class based on compound score from VADER

# %%
def sentiment_Classification(x):
    if x['compound'] >= 0.05:
        return 'positive'
    elif  (x['compound'] > -0.05) and (x['compound'] < 0.05):
        return 'neutral'
    elif x['compound'] <= -0.05  :
        return 'negative'

# %% [markdown]
# **5.)** Intialize VADER sentiment analyzer

# %%
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# **6.)** Clean text, remove stopwords, do sentiment analysis

# %%
df['text'] = df['text'].apply(clean_Text)
df['text'] = df['text'].apply(remove_stop)
df['sentiment'] = df['text'].apply(sentiment_analyzer)
df['sentiment_category'] = df['sentiment'].apply(sentiment_Classification)

# %%
sentiment_category = df['sentiment_category'].value_counts()

# %%
sentiment_category
# Out:
# positive    22628
# negative    12949
# neutral      8602
# Name: sentiment_category, dtype: int64

# %%
plt.figure(figsize=(14,8))
sns.countplot(df['sentiment_category'])
plt.title('Number of tweets V/S Month');

# %% [markdown]
# ## GENERATING WORDCLOUDS FOR POSITIVE AND NEGATIVE TWEETS

# %%
positive_tweets = ''
negative_tweets = ''

# %%
for index in df.index :
    if (df.iloc[index]['sentiment_category']=='positive'):
        positive_tweets = positive_tweets + ' ' + df.iloc[index]['text']

# %%
#positive_tweets

# %%
stopwords = set(STOPWORDS)
stopwords.update(['https', 'co','t','d','n','viru'])
wordcloud = WordCloud(background_color="white",width=1600, height=800,stopwords=stopwords).generate(positive_tweets)
plt.figure(figsize=(14,10),facecolor='k')
plt.axis('off')
plt.imshow(wordcloud,interpolation='bilinear')
plt.show();
